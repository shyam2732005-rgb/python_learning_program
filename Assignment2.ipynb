# %%
color=input("inset trafic color")
if color == red:
    print("stop")
elif  color == yellow:
    print("ready")
elif color == green:
    print("go")
else:
    print("invalid color")
# Out:
# inset trafic color gj
# invalid color

# %%
weather=input("weather checker")
if  weather == "sunny":
    print("go outdide")
elif weather == "rainy":
    print("take an umberla")
elif weather == "cloudy":
    print("it may rain")
else:
    print("invalid weather")
# Out:
# weather checker rainy
# take an umberla

# %%
grade=input("enter the grade")
if grade=="a":
    print("excellent")
elif grade=="b":  
    print("good")
elif grade=="c": 
    print("needs improvements")
else:
    print("invalid grade")
# Out:
# enter the grade b
# good

# %%
vehicle = input("enter the vehicle")
if vehicle =="bike":
    print("two wheeler")
elif vehicle =="car":
    print("four wheeler")
elif vehicle =="bus": 
    print("public vehicle")
else:
    print("no vehicle")
# Out:
# enter the vehicle rali
# no vehicle

# %%
score = int(input("enter the number"))
if score<35:
      print("poor student")
elif  score>35 and score<70:
      print("average student") 
elif  score>70 and score<100:
      print("good student")
else:
    print("invalid score")
# Out:
# enter the number 80
# good student

# %%
a=int(input("enter the number"))
b=int(input("enter the number"))
operation=input("add/sub/mul/div:")
if operation=="add":
     print(a+b)
elif operation=="sub":
    print(a-b)
elif operation=="mul":
    print(a*b)
elif operation=="div":
    print(a/b)
else:
    print("invalid operation")
# Out:
# enter the number 200
# enter the number 250
# add/sub/mul/div: div
# 0.8

# %%
score =int(input("score"))
if score >70:
    name=input("enter the name")
    age =int(input("enter the age"))
    print("eligible")
else:
    print("not eligible")
# Out:
# score 65
# not eligible

# %%
salary = int(input("salary"))
age = int(input("age"))
if salary>20000 or age<25:
    loan=int(input("loan"))
    if loan>50000:
        print("max loan amount 50000")
    else:
     print("eligible loan")
else:
    print("not eligible")
# Out:
# salary 25000
# age 27
# loan 60000
# max loan amount 50000

# %%
temperature = int(input("check"))
if temperature <20:
    print("cold")
elif temperature>20 and temperature<30:
    print("normal")
elif temperature>30:
    print("hot")
# Out:
# check 15
# cold

# %%
theater = int(input("enter the amount"))
if theater>50:
    discount=theater*10/50
    balance=theater-discount
    print("balance",balance)

else:
    print("not eligible")
# Out:
# enter the amount 60
# balance 48.0

# %%
student = int(input("enter the mark"))
if student >40:
    print("pass")
else:
    print("fail")
# Out:
# enter the mark 50
# pass

# %%
balance=int(input("enter the balance"))
withrawal=int(input("enter tne withrawal"))
if balance>=withrawal:
    bank = balance - withrawal
    print("succusfully withrawal")
    print("bank",bank)
else:
    print("insufficient")
# Out:
# enter the balance 1000
# enter tne withrawal 2000
# insufficient
